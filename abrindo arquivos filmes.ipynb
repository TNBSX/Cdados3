# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import expon

# %%
#Abrir o arquivo
name = pd.read_csv('name.tsv',sep='\t')
#listar colunas
print(list(name))
# Out:
# ['nconst', 'primaryName', 'birthYear', 'deathYear', 'primaryProfession', 'knownForTitles']

# %%
isso = name[:500]
isso
# Out:
#         nconst           primaryName birthYear deathYear  \
# 0    nm0000001          Fred Astaire      1899      1987
# 1    nm0000002         Lauren Bacall      1924      2014
# 2    nm0000003       Brigitte Bardot      1934        \N
# 3    nm0000004          John Belushi      1949      1982
# 4    nm0000005        Ingmar Bergman      1918      2007
# 5    nm0000006        Ingrid Bergman      1915      1982
# 6    nm0000007       Humphrey Bogart      1899      1957
# 7    nm0000008         Marlon Brando      1924      2004
# 8    nm0000009        Richard Burton      1925      1984
# 9    nm0000010          James Cagney      1899      1986
# 10   nm0000011           Gary Cooper      1901      1961
# 11   nm0000012           Bette Davis      1908      1989
# 12   nm0000013             Doris Day      1922        \N
# 13   nm0000014   Olivia de Havilland      1916        \N
# 14   nm0000015            James Dean      1931      1955
# 15   nm0000016       Georges Delerue      1925      1992
# 16   nm0000017      Marlene Dietrich      1901      1992
# 17   nm0000018          Kirk Douglas      1916        \N
# 18   nm0000019      Federico Fellini      1920      1993
# 19   nm0000020           Henry Fonda      1905      1982
# 20   nm0000021         Joan Fontaine      1917      2013
# 21   nm0000022           Clark Gable      1901      1960
# 22   nm0000023          Judy Garland      1922      1969
# 23   nm0000024          John Gielgud      1904      2000
# 24   nm0000025       Jerry Goldsmith      1929      2004
# 25   nm0000026            Cary Grant      1904      1986
# 26   nm0000027         Alec Guinness      1914      2000
# 27   nm0000028         Rita Hayworth      1918      1987
# 28   nm0000029     Margaux Hemingway      1954      1996
# 29   nm0000030        Audrey Hepburn      1929      1993
# ..         ...                   ...       ...       ...
# 470  nm0000471            Raul Julia      1940      1994
# 471  nm0000472         Boris Karloff      1887      1969
# 472  nm0000473          Diane Keaton      1946        \N
# 473  nm0000474        Michael Keaton      1951        \N
# 474  nm0000475          Patsy Kensit      1968        \N
# 475  nm0000476        Sally Kirkland      1941        \N
# 476  nm0000477          Mia Kirshner      1975        \N
# 477  nm0000478          Tawny Kitaen      1961        \N
# 478  nm0000479         Walter Koenig      1936        \N
# 479  nm0000480          Elias Koteas      1961        \N
# 480  nm0000481           Alice Krige      1954        \N
# 481  nm0000482        Sylvia Kristel      1952      2012
# 482  nm0000483   Christopher Lambert      1957        \N
# 483  nm0000484           John Landis      1950        \N
# 484  nm0000485            Fritz Lang      1890      1976
# 485  nm0000486    Heather Langenkamp      1964        \N
# 486  nm0000487               Ang Lee      1954        \N
# 487  nm0000488           Brandon Lee      1965      1993
# 488  nm0000489       Christopher Lee      1922      2015
# 489  nm0000490             Spike Lee      1957        \N
# 490  nm0000491        John Leguizamo      1964        \N
# 491  nm0000492  Jennifer Jason Leigh      1962        \N
# 492  nm0000493           Jack Lemmon      1925      2001
# 493  nm0000494   Robert Sean Leonard      1969        \N
# 494  nm0000495             Téa Leoni      1966        \N
# 495  nm0000496        Juliette Lewis      1973        \N
# 496  nm0000497         Jennifer Lien      1974        \N
# 497  nm0000498       Matthew Lillard      1970        \N
# 498  nm0000499              Bai Ling      1966        \N
# 499  nm0000500     Richard Linklater      1960        \N
#
#                               primaryProfession  \
# 0                soundtrack,actor,miscellaneous
# 1                            actress,soundtrack
# 2                   actress,soundtrack,producer
# 3                       actor,writer,soundtrack
# 4                         writer,director,actor
# 5                   actress,soundtrack,producer
# 6                     actor,soundtrack,producer
# 7                     actor,soundtrack,director
# 8                     actor,producer,soundtrack
# 9                     actor,soundtrack,director
# 10                    actor,soundtrack,producer
# 11        actress,soundtrack,make_up_department
# 12                  soundtrack,actress,producer
# 13                           actress,soundtrack
# 14                          actor,miscellaneous
# 15         composer,soundtrack,music_department
# 16          soundtrack,actress,music_department
# 17                    actor,producer,soundtrack
# 18           writer,director,assistant_director
# 19                    actor,producer,soundtrack
# 20                  actress,soundtrack,producer
# 21                    actor,soundtrack,producer
# 22                           soundtrack,actress
# 23                        actor,writer,director
# 24         music_department,soundtrack,composer
# 25                    actor,soundtrack,producer
# 26                      actor,soundtrack,writer
# 27                  actress,soundtrack,producer
# 28                        actress,miscellaneous
# 29                           actress,soundtrack
# ..                                          ...
# 470                            actor,soundtrack
# 471                            actor,soundtrack
# 472                   actress,producer,director
# 473                   actor,producer,soundtrack
# 474                          actress,soundtrack
# 475              actress,producer,miscellaneous
# 476                                     actress
# 477                            actress,producer
# 478                       actor,writer,producer
# 479                              actor,producer
# 480                     actress,producer,writer
# 481                 actress,soundtrack,director
# 482                       actor,producer,writer
# 483                     producer,director,actor
# 484                    director,writer,producer
# 485  actress,special_effects,make_up_department
# 486                    director,producer,writer
# 487                         actor,miscellaneous
# 488                   actor,soundtrack,producer
# 489                    director,producer,writer
# 490                       actor,writer,producer
# 491                 actress,producer,soundtrack
# 492                   actor,soundtrack,producer
# 493                            actor,soundtrack
# 494                            actress,producer
# 495                 actress,soundtrack,director
# 496              actress,producer,miscellaneous
# 497                   actor,producer,soundtrack
# 498                     actress,producer,writer
# 499                    producer,director,writer
#
#                               knownForTitles
# 0    tt0050419,tt0072308,tt0053137,tt0043044
# 1    tt0038355,tt0117057,tt0037382,tt0071877
# 2    tt0057345,tt0054452,tt0049189,tt0059956
# 3    tt0080455,tt0072562,tt0077975,tt0078723
# 4    tt0083922,tt0050976,tt0050986,tt0060827
# 5    tt0071877,tt0038787,tt0038109,tt0034583
# 6    tt0033870,tt0037382,tt0043265,tt0034583
# 7    tt0070849,tt0078788,tt0047296,tt0068646
# 8    tt0059749,tt0087803,tt0061184,tt0057877
# 9    tt0055256,tt0031867,tt0029870,tt0035575
# 10   tt0052876,tt0027996,tt0034167,tt0044706
# 11   tt0042192,tt0056687,tt0035140,tt0031210
# 12   tt0060463,tt0055100,tt0053172,tt0048317
# 13   tt0041452,tt0040806,tt0029843,tt0031381
# 14   tt0048028,tt0048545,tt0045458,tt0049261
# 15   tt0091763,tt0096320,tt0069946,tt0078122
# 16   tt0021156,tt0055031,tt0051201,tt0052311
# 17   tt0080736,tt0054331,tt0052365,tt0049456
# 18   tt0071129,tt0056801,tt0053779,tt0047528
# 19   tt0032551,tt0050083,tt0064116,tt0082846
# 20   tt0032976,tt0034248,tt0039504,tt0036969
# 21   tt0026205,tt0026752,tt0025316,tt0031381
# 22   tt0047522,tt0032138,tt0055031,tt0037059
# 23   tt0082031,tt0045943,tt0117631,tt0071877
# 24   tt0117731,tt0119488,tt0112715,tt0100802
# 25   tt0056923,tt0036613,tt0048728,tt0053125
# 26   tt0050212,tt0051739,tt0076759,tt0041546
# 27   tt0036723,tt0038559,tt0040552,tt0040525
# 28   tt0102122,tt0077800,tt0074802,tt0110138
# 29   tt0046250,tt0058385,tt0054698,tt0056923
# ..                                       ...
# 470  tt0089424,tt0106220,tt0101272,tt0111301
# 471  tt0023245,tt0026138,tt0024894,tt0060345
# 472  tt0079522,tt0337741,tt0075686,tt0356680
# 473  tt2562232,tt0094721,tt1895587,tt4276820
# 474  tt0090585,tt0068069,tt0079268,tt0097733
# 475  tt0131369,tt0102138,tt0092569,tt3216866
# 476            tt0387877,tt0330251,tt3520702
# 477  tt0086793,tt0086927,tt0087903,tt0111999
# 478  tt0060028,tt0102975,tt0092007,tt0084726
# 479  tt0822854,tt0114194,tt0115964,tt0120863
# 480  tt0105428,tt1981115,tt0384537,tt0117731
# 481  tt0079152,tt0071464,tt0072933,tt0078740
# 482  tt0120604,tt0091203,tt0090095,tt0113855
# 483  tt0118747,tt0086491,tt0080455,tt0082010
# 484  tt0019901,tt0057345,tt0022100,tt0017136
# 485  tt0087800,tt0093629,tt0094490,tt0111686
# 486  tt0114388,tt0190332,tt0454876,tt0808357
# 487  tt0091428,tt0105219,tt0109506,tt0102915
# 488  tt0120737,tt0121765,tt0167261,tt0070917
# 489  tt0097216,tt0091939,tt7349662,tt0104797
# 490  tt0117509,tt0203009,tt0120177,tt0119887
# 491  tt0105414,tt0109642,tt2401878,tt3460252
# 492  tt0104348,tt0053291,tt0053604,tt0107050
# 493  tt0108265,tt0106226,tt0097165,tt0412142
# 494  tt0163025,tt0120647,tt0371246,tt0218967
# 495  tt1322269,tt0116367,tt0110632,tt0101540
# 496  tt0120586,tt0127385,tt0106100,tt0112178
# 497  tt0267913,tt0133189,tt1033575,tt0331632
# 498  tt0405336,tt0119994,tt0109506,tt1121931
# 499  tt1065073,tt0405296,tt0243017,tt2209418
#
# [500 rows x 6 columns]

# %%
isso.drop('knownForTitles', axis=1).join(isso['knownForTitles'].str.split(',', expand=True).stack().reset_index(level=1, drop=True).rename('knownForTitles'))
# Out:
#         nconst          primaryName birthYear deathYear  \
# 0    nm0000001         Fred Astaire      1899      1987
# 0    nm0000001         Fred Astaire      1899      1987
# 0    nm0000001         Fred Astaire      1899      1987
# 0    nm0000001         Fred Astaire      1899      1987
# 1    nm0000002        Lauren Bacall      1924      2014
# 1    nm0000002        Lauren Bacall      1924      2014
# 1    nm0000002        Lauren Bacall      1924      2014
# 1    nm0000002        Lauren Bacall      1924      2014
# 2    nm0000003      Brigitte Bardot      1934        \N
# 2    nm0000003      Brigitte Bardot      1934        \N
# 2    nm0000003      Brigitte Bardot      1934        \N
# 2    nm0000003      Brigitte Bardot      1934        \N
# 3    nm0000004         John Belushi      1949      1982
# 3    nm0000004         John Belushi      1949      1982
# 3    nm0000004         John Belushi      1949      1982
# 3    nm0000004         John Belushi      1949      1982
# 4    nm0000005       Ingmar Bergman      1918      2007
# 4    nm0000005       Ingmar Bergman      1918      2007
# 4    nm0000005       Ingmar Bergman      1918      2007
# 4    nm0000005       Ingmar Bergman      1918      2007
# 5    nm0000006       Ingrid Bergman      1915      1982
# 5    nm0000006       Ingrid Bergman      1915      1982
# 5    nm0000006       Ingrid Bergman      1915      1982
# 5    nm0000006       Ingrid Bergman      1915      1982
# 6    nm0000007      Humphrey Bogart      1899      1957
# 6    nm0000007      Humphrey Bogart      1899      1957
# 6    nm0000007      Humphrey Bogart      1899      1957
# 6    nm0000007      Humphrey Bogart      1899      1957
# 7    nm0000008        Marlon Brando      1924      2004
# 7    nm0000008        Marlon Brando      1924      2004
# ..         ...                  ...       ...       ...
# 492  nm0000493          Jack Lemmon      1925      2001
# 492  nm0000493          Jack Lemmon      1925      2001
# 493  nm0000494  Robert Sean Leonard      1969        \N
# 493  nm0000494  Robert Sean Leonard      1969        \N
# 493  nm0000494  Robert Sean Leonard      1969        \N
# 493  nm0000494  Robert Sean Leonard      1969        \N
# 494  nm0000495            Téa Leoni      1966        \N
# 494  nm0000495            Téa Leoni      1966        \N
# 494  nm0000495            Téa Leoni      1966        \N
# 494  nm0000495            Téa Leoni      1966        \N
# 495  nm0000496       Juliette Lewis      1973        \N
# 495  nm0000496       Juliette Lewis      1973        \N
# 495  nm0000496       Juliette Lewis      1973        \N
# 495  nm0000496       Juliette Lewis      1973        \N
# 496  nm0000497        Jennifer Lien      1974        \N
# 496  nm0000497        Jennifer Lien      1974        \N
# 496  nm0000497        Jennifer Lien      1974        \N
# 496  nm0000497        Jennifer Lien      1974        \N
# 497  nm0000498      Matthew Lillard      1970        \N
# 497  nm0000498      Matthew Lillard      1970        \N
# 497  nm0000498      Matthew Lillard      1970        \N
# 497  nm0000498      Matthew Lillard      1970        \N
# 498  nm0000499             Bai Ling      1966        \N
# 498  nm0000499             Bai Ling      1966        \N
# 498  nm0000499             Bai Ling      1966        \N
# 498  nm0000499             Bai Ling      1966        \N
# 499  nm0000500    Richard Linklater      1960        \N
# 499  nm0000500    Richard Linklater      1960        \N
# 499  nm0000500    Richard Linklater      1960        \N
# 499  nm0000500    Richard Linklater      1960        \N
#
#                   primaryProfession knownForTitles
# 0    soundtrack,actor,miscellaneous      tt0050419
# 0    soundtrack,actor,miscellaneous      tt0072308
# 0    soundtrack,actor,miscellaneous      tt0053137
# 0    soundtrack,actor,miscellaneous      tt0043044
# 1                actress,soundtrack      tt0038355
# 1                actress,soundtrack      tt0117057
# 1                actress,soundtrack      tt0037382
# 1                actress,soundtrack      tt0071877
# 2       actress,soundtrack,producer      tt0057345
# 2       actress,soundtrack,producer      tt0054452
# 2       actress,soundtrack,producer      tt0049189
# 2       actress,soundtrack,producer      tt0059956
# 3           actor,writer,soundtrack      tt0080455
# 3           actor,writer,soundtrack      tt0072562
# 3           actor,writer,soundtrack      tt0077975
# 3           actor,writer,soundtrack      tt0078723
# 4             writer,director,actor      tt0083922
# 4             writer,director,actor      tt0050976
# 4             writer,director,actor      tt0050986
# 4             writer,director,actor      tt0060827
# 5       actress,soundtrack,producer      tt0071877
# 5       actress,soundtrack,producer      tt0038787
# 5       actress,soundtrack,producer      tt0038109
# 5       actress,soundtrack,producer      tt0034583
# 6         actor,soundtrack,producer      tt0033870
# 6         actor,soundtrack,producer      tt0037382
# 6         actor,soundtrack,producer      tt0043265
# 6         actor,soundtrack,producer      tt0034583
# 7         actor,soundtrack,director      tt0070849
# 7         actor,soundtrack,director      tt0078788
# ..                              ...            ...
# 492       actor,soundtrack,producer      tt0053604
# 492       actor,soundtrack,producer      tt0107050
# 493                actor,soundtrack      tt0108265
# 493                actor,soundtrack      tt0106226
# 493                actor,soundtrack      tt0097165
# 493                actor,soundtrack      tt0412142
# 494                actress,producer      tt0163025
# 494                actress,producer      tt0120647
# 494                actress,producer      tt0371246
# 494                actress,producer      tt0218967
# 495     actress,soundtrack,director      tt1322269
# 495     actress,soundtrack,director      tt0116367
# 495     actress,soundtrack,director      tt0110632
# 495     actress,soundtrack,director      tt0101540
# 496  actress,producer,miscellaneous      tt0120586
# 496  actress,producer,miscellaneous      tt0127385
# 496  actress,producer,miscellaneous      tt0106100
# 496  actress,producer,miscellaneous      tt0112178
# 497       actor,producer,soundtrack      tt0267913
# 497       actor,producer,soundtrack      tt0133189
# 497       actor,producer,soundtrack      tt1033575
# 497       actor,producer,soundtrack      tt0331632
# 498         actress,producer,writer      tt0405336
# 498         actress,producer,writer      tt0119994
# 498         actress,producer,writer      tt0109506
# 498         actress,producer,writer      tt1121931
# 499        producer,director,writer      tt1065073
# 499        producer,director,writer      tt0405296
# 499        producer,director,writer      tt0243017
# 499        producer,director,writer      tt2209418
#
# [1993 rows x 6 columns]

# %%
# name
#.join(name['knownForTitles'].str.split(",",expand=True))
from collections import defaultdict as ddict

d = ddict(list)

for i in isso.index:
    filme = isso[isso.index == i]
    titles = filme['knownForTitles'].apply(lambda x: x.split(','))
    filme = filme.drop('knownForTitles',axis=1)
    for k in titles.values[0]:
        d[k].append(filme)

# %%
print(d)
# Out:
# defaultdict(<class 'list'>, {'tt0050419': [      nconst   primaryName birthYear deathYear               primaryProfession
# 0  nm0000001  Fred Astaire      1899      1987  soundtrack,actor,miscellaneous], 'tt0072308': [      nconst   primaryName birthYear deathYear               primaryProfession
# 0  nm0000001  Fred Astaire      1899      1987  soundtrack,actor,miscellaneous,         nconst          primaryName birthYear deathYear  \
# 327  nm0000328  Richard Chamberlain      1934        \N
#
#              primaryProfession
# 327  actor,soundtrack,producer  ], 'tt0053137': [      nconst   primaryName birthYear deathYear               primaryProfession
# 0  nm0000001  Fred Astaire      1899      1987  soundtrack,actor,miscellaneous], 'tt0043044': [      nconst   primaryName birthYear deathYear               primaryProfession
# 0  nm0000001  Fred Astaire      1899      1987  soundtrack,actor,miscellaneous], 'tt0038355': [      nconst    primaryName birthYear deathYear   primaryProfession
# 1  nm0000002  Lauren Bacall      1924      2014  actress,soundtrack], 'tt0117057': [      nconst    primaryName birthYear deathYear   primaryProfession
# 1  nm0000002  Lauren Bacall      1924      2014  actress,soundtrack], 'tt0037382': [      nconst    primaryName birthYear deathYear   primaryProfession
# 1  nm0000002  Lauren Bacall      1924      2014  actress,soundtrack,       nconst      primaryName birthYear deathYear          primaryProfession
# 6  nm0000007  Humphrey Bogart      1899      1957  actor,soundtrack,producer], 'tt0071877': [      nconst    primaryName birthYear deathYear   primaryProfession
# 1  nm0000002  Lauren Bacall      1924      2014  actress,soundtrack,       nconst     primaryName birthYear deathYear            primaryProfession
# 5  nm0000006  Ingrid Bergman      1915      1982  actress,soundtrack,producer,        nconst   primaryName birthYear deathYear      primaryProfession
# 23  nm0000024  John Gielgud      1904      2000  actor,writer,director,         nconst        primaryName birthYear deathYear primaryProfession
# 301  nm0000302  Jacqueline Bisset      1944        \N  actress,producer], 'tt0057345': [      nconst      primaryName birthYear deathYear            primaryProfession
# 2  nm0000003  Brigitte Bardot      1934        \N  actress,soundtrack,producer,         nconst primaryName birthYear deathYear         primaryProfession
# 484  nm0000485  Fritz Lang      1890      1976  director,writer,producer], 'tt0054452': [      nconst      primaryName birthYear deathYear            primaryProfession
# 2  nm0000003  Brigitte Bardot      1934        \N  actress,soundtrack,producer], 'tt0049189': [      nconst      primaryName birthYear deathYear            primaryProfession
# 2  nm0000003  Brigitte Bardot      1934        \N  actress,soundtrack,producer], 'tt0059956': [      nconst      primaryName birthYear deathYear            primaryProfession
# 2  nm0000003  Brigitte Bardot      1934        \N  actress,soundtrack,producer], 'tt0080455': [      nconst   primaryName birthYear deathYear        primaryProfession
# 3  nm0000004  John Belushi      1949      1982  actor,writer,soundtrack,         nconst  primaryName birthYear deathYear      primaryProfession
# 100  nm0000101  Dan Aykroyd      1952        \N  writer,actor,producer,         nconst  primaryName birthYear deathYear        primaryProfession
# 483  nm0000484  John Landis      1950        \N  producer,director,actor], 'tt0072562': [      nconst   primaryName birthYear deathYear        primaryProfession
# 3  nm0000004  John Belushi      1949      1982  actor,writer,soundtrack], 'tt0077975': [      nconst   primaryName birthYear deathYear        primaryProfession
# 3  nm0000004  John Belushi      1949      1982  actor,writer,soundtrack,         nconst  primaryName birthYear deathYear            primaryProfession
# 260  nm0000261  Karen Allen      1951        \N  actress,director,soundtrack], 'tt0078723': [      nconst   primaryName birthYear deathYear        primaryProfession
# 3  nm0000004  John Belushi      1949      1982  actor,writer,soundtrack], 'tt0083922': [      nconst     primaryName birthYear deathYear      primaryProfession
# 4  nm0000005  Ingmar Bergman      1918      2007  writer,director,actor], 'tt0050976': [      nconst     primaryName birthYear deathYear      primaryProfession
# 4  nm0000005  Ingmar Bergman      1918      2007  writer,director,actor], 'tt0050986': [      nconst     primaryName birthYear deathYear      primaryProfession
# 4  nm0000005  Ingmar Bergman      1918      2007  writer,director,actor], 'tt0060827': [      nconst     primaryName birthYear deathYear      primaryProfession
# 4  nm0000005  Ingmar Bergman      1918      2007  writer,director,actor], 'tt0038787': [      nconst     primaryName birthYear deathYear            primaryProfession
# 5  nm0000006  Ingrid Bergman      1915      1982  actress,soundtrack,producer], 'tt0038109': [      nconst     primaryName birthYear deathYear            primaryProfession
# 5  nm0000006  Ingrid Bergman      1915      1982  actress,soundtrack,producer,        nconst   primaryName birthYear deathYear  \
# 66  nm0000067  Miklós Rózsa      1907      1995
#
#                        primaryProfession
# 66  music_department,composer,soundtrack  ], 'tt0034583': [      nconst     primaryName birthYear deathYear            primaryProfession
# 5  nm0000006  Ingrid Bergman      1915      1982  actress,soundtrack,producer,       nconst      primaryName birthYear deathYear          primaryProfession
# 6  nm0000007  Humphrey Bogart      1899      1957  actor,soundtrack,producer,        nconst  primaryName birthYear deathYear        primaryProfession
# 47  nm0000048  Peter Lorre      1904      1964  actor,soundtrack,writer,        nconst  primaryName birthYear deathYear  \
# 69  nm0000070  Max Steiner      1888      1971
#
#                        primaryProfession
# 69  music_department,composer,soundtrack  ], 'tt0033870': [      nconst      primaryName birthYear deathYear          primaryProfession
# 6  nm0000007  Humphrey Bogart      1899      1957  actor,soundtrack,producer,        nconst  primaryName birthYear deathYear        primaryProfession
# 47  nm0000048  Peter Lorre      1904      1964  actor,soundtrack,writer], 'tt0043265': [      nconst      primaryName birthYear deathYear          primaryProfession
# 6  nm0000007  Humphrey Bogart      1899      1957  actor,soundtrack,producer,        nconst        primaryName birthYear deathYear  \
# 30  nm0000031  Katharine Hepburn      1907      2003
#
#             primaryProfession
# 30  actress,soundtrack,writer  ], 'tt0070849': [      nconst    primaryName birthYear deathYear          primaryProfession
# 7  nm0000008  Marlon Brando      1924      2004  actor,soundtrack,director], 'tt0078788': [      nconst    primaryName birthYear deathYear          primaryProfession
# 7  nm0000008  Marlon Brando      1924      2004  actor,soundtrack,director,         nconst           primaryName birthYear deathYear  \
# 337  nm0000338  Francis Ford Coppola      1939        \N
#
#             primaryProfession
# 337  producer,director,writer  ,         nconst    primaryName birthYear deathYear          primaryProfession
# 379  nm0000380  Robert Duvall      1931        \N  actor,producer,soundtrack], 'tt0047296': [      nconst    primaryName birthYear deathYear          primaryProfession
# 7  nm0000008  Marlon Brando      1924      2004  actor,soundtrack,director], 'tt0068646': [      nconst    primaryName birthYear deathYear          primaryProfession
# 7  nm0000008  Marlon Brando      1924      2004  actor,soundtrack,director,        nconst primaryName birthYear deathYear  \
# 64  nm0000065   Nino Rota      1911      1979
#
#                        primaryProfession
# 64  composer,soundtrack,music_department  ,         nconst primaryName birthYear deathYear          primaryProfession
# 198  nm0000199   Al Pacino      1940        \N  actor,soundtrack,director,         nconst           primaryName birthYear deathYear  \
# 337  nm0000338  Francis Ford Coppola      1939        \N
#
#             primaryProfession
# 337  producer,director,writer  ,         nconst    primaryName birthYear deathYear          primaryProfession
# 379  nm0000380  Robert Duvall      1931        \N  actor,producer,soundtrack], 'tt0059749': [      nconst     primaryName birthYear deathYear          primaryProfession
# 8  nm0000009  Richard Burton      1925      1984  actor,producer,soundtrack], 'tt0087803': [      nconst     primaryName birthYear deathYear          primaryProfession
# 8  nm0000009  Richard Burton      1925      1984  actor,producer,soundtrack,         nconst primaryName birthYear deathYear primaryProfession
# 456  nm0000457   John Hurt      1940      2017  actor,soundtrack], 'tt0061184': [      nconst     primaryName birthYear deathYear          primaryProfession
# 8  nm0000009  Richard Burton      1925      1984  actor,producer,soundtrack,        nconst       primaryName birthYear deathYear  \
# 71  nm0000072  Elizabeth Taylor      1932      2011
#
#               primaryProfession
# 71  actress,soundtrack,producer  ], 'tt0057877': [      nconst     primaryName birthYear deathYear          primaryProfession
# 8  nm0000009  Richard Burton      1925      1984  actor,producer,soundtrack], 'tt0055256': [      nconst   primaryName birthYear deathYear          primaryProfession
# 9  nm0000010  James Cagney      1899      1986  actor,soundtrack,director], 'tt0031867': [      nconst   primaryName birthYear deathYear          primaryProfession
# 9  nm0000010  James Cagney      1899      1986  actor,soundtrack,director], 'tt0029870': [      nconst   primaryName birthYear deathYear          primaryProfession
# 9  nm0000010  James Cagney      1899      1986  actor,soundtrack,director], 'tt0035575': [      nconst   primaryName birthYear deathYear          primaryProfession
# 9  nm0000010  James Cagney      1899      1986  actor,soundtrack,director], 'tt0052876': [       nconst  primaryName birthYear deathYear          primaryProfession
# 10  nm0000011  Gary Cooper      1901      1961  actor,soundtrack,producer], 'tt0027996': [       nconst  primaryName birthYear deathYear          primaryProfession
# 10  nm0000011  Gary Cooper      1901      1961  actor,soundtrack,producer], 'tt0034167': [       nconst  primaryName birthYear deathYear          primaryProfession
# 10  nm0000011  Gary Cooper      1901      1961  actor,soundtrack,producer], 'tt0044706': [       nconst  primaryName birthYear deathYear          primaryProfession
# 10  nm0000011  Gary Cooper      1901      1961  actor,soundtrack,producer,        nconst  primaryName birthYear deathYear   primaryProfession
# 37  nm0000038  Grace Kelly      1929      1982  actress,soundtrack], 'tt0042192': [       nconst  primaryName birthYear deathYear  \
# 11  nm0000012  Bette Davis      1908      1989
#
#                         primaryProfession
# 11  actress,soundtrack,make_up_department  ,        nconst    primaryName birthYear deathYear  \
# 54  nm0000055  Alfred Newman      1901      1970
#
#                        primaryProfession
# 54  music_department,composer,soundtrack  ], 'tt0056687': [       nconst  primaryName birthYear deathYear  \
# 11  nm0000012  Bette Davis      1908      1989
#
#                         primaryProfession
# 11  actress,soundtrack,make_up_department  ], 'tt0035140': [       nconst  primaryName birthYear deathYear  \
# 11  nm0000012  Bette Davis      1908      1989
#
#                         primaryProfession
# 11  actress,soundtrack,make_up_department  ], 'tt0031210': [       nconst  primaryName birthYear deathYear  \
# 11  nm0000012  Bette Davis      1908      1989
#
#                         primaryProfession
# 11  actress,soundtrack,make_up_department  ], 'tt0060463': [       nconst primaryName birthYear deathYear            primaryProfession
# 12  nm0000013   Doris Day      1922        \N  soundtrack,actress,producer], 'tt0055100': [       nconst primaryName birthYear deathYear            primaryProfession
# 12  nm0000013   Doris Day      1922        \N  soundtrack,actress,producer], 'tt0053172': [       nconst primaryName birthYear deathYear            primaryProfession
# 12  nm0000013   Doris Day      1922        \N  soundtrack,actress,producer], 'tt0048317': [       nconst primaryName birthYear deathYear            primaryProfession
# 12  nm0000013   Doris Day      1922        \N  soundtrack,actress,producer], 'tt0041452': [       nconst          primaryName birthYear deathYear   primaryProfession
# 13  nm0000014  Olivia de Havilland      1916        \N  actress,soundtrack], 'tt0040806': [       nconst          primaryName birthYear deathYear   primaryProfession
# 13  nm0000014  Olivia de Havilland      1916        \N  actress,soundtrack], 'tt0029843': [       nconst          primaryName birthYear deathYear   primaryProfession
# 13  nm0000014  Olivia de Havilland      1916        \N  actress,soundtrack], 'tt0031381': [       nconst          primaryName birthYear deathYear   primaryProfession
# 13  nm0000014  Olivia de Havilland      1916        \N  actress,soundtrack,        nconst  primaryName birthYear deathYear          primaryProfession
# 21  nm0000022  Clark Gable      1901      1960  actor,soundtrack,producer,        nconst   primaryName birthYear deathYear          primaryProfession
# 45  nm0000046  Vivien Leigh      1913      1967  actress,soundtrack,writer,        nconst  primaryName birthYear deathYear  \
# 69  nm0000070  Max Steiner      1888      1971
#
#                        primaryProfession
# 69  music_department,composer,soundtrack  ], 'tt0048028': [       nconst primaryName birthYear deathYear    primaryProfession
# 14  nm0000015  James Dean      1931      1955  actor,miscellaneous], 'tt0048545': [       nconst primaryName birthYear deathYear    primaryProfession
# 14  nm0000015  James Dean      1931      1955  actor,miscellaneous,        nconst   primaryName birthYear deathYear  \
# 80  nm0000081  Natalie Wood      1938      1981
#
#                       primaryProfession
# 80  actress,soundtrack,music_department  ], 'tt0045458': [       nconst primaryName birthYear deathYear    primaryProfession
# 14  nm0000015  James Dean      1931      1955  actor,miscellaneous], 'tt0049261': [       nconst primaryName birthYear deathYear    primaryProfession
# 14  nm0000015  James Dean      1931      1955  actor,miscellaneous], 'tt0091763': [       nconst      primaryName birthYear deathYear  \
# 15  nm0000016  Georges Delerue      1925      1992
#
#                        primaryProfession
# 15  composer,soundtrack,music_department  ,         nconst   primaryName birthYear deathYear         primaryProfession
# 230  nm0000231  Oliver Stone      1946        \N  director,producer,writer,         nconst   primaryName birthYear deathYear      primaryProfession
# 296  nm0000297  Tom Berenger      1949        \N  actor,producer,writer], 'tt0096320': [       nconst      primaryName birthYear deathYear  \
# 15  nm0000016  Georges Delerue      1925      1992
#
#                        primaryProfession
# 15  composer,soundtrack,music_department  ], 'tt0069946': [       nconst      primaryName birthYear deathYear  \
# 15  nm0000016  Georges Delerue      1925      1992
#
#                        primaryProfession
# 15  composer,soundtrack,music_department  ], 'tt0078122': [       nconst      primaryName birthYear deathYear  \
# 15  nm0000016  Georges Delerue      1925      1992
#
#                        primaryProfession
# 15  composer,soundtrack,music_department  ], 'tt0021156': [       nconst       primaryName birthYear deathYear  \
# 16  nm0000017  Marlene Dietrich      1901      1992
#
#                       primaryProfession
# 16  soundtrack,actress,music_department  ], 'tt0055031': [       nconst       primaryName birthYear deathYear  \
# 16  nm0000017  Marlene Dietrich      1901      1992
#
#                       primaryProfession
# 16  soundtrack,actress,music_department  ,        nconst   primaryName birthYear deathYear   primaryProfession
# 22  nm0000023  Judy Garland      1922      1969  soundtrack,actress,        nconst    primaryName birthYear deathYear primaryProfession
# 74  nm0000075  Spencer Tracy      1900      1967  actor,soundtrack], 'tt0051201': [       nconst       primaryName birthYear deathYear  \
# 16  nm0000017  Marlene Dietrich      1901      1992
#
#                       primaryProfession
# 16  soundtrack,actress,music_department  ,        nconst   primaryName birthYear deathYear          primaryProfession
# 60  nm0000061  Tyrone Power      1914      1958  actor,soundtrack,producer], 'tt0052311': [       nconst       primaryName birthYear deathYear  \
# 16  nm0000017  Marlene Dietrich      1901      1992
#
#                       primaryProfession
# 16  soundtrack,actress,music_department  ,        nconst   primaryName birthYear deathYear      primaryProfession
# 79  nm0000080  Orson Welles      1915      1985  actor,director,writer], 'tt0080736': [       nconst   primaryName birthYear deathYear          primaryProfession
# 17  nm0000018  Kirk Douglas      1916        \N  actor,producer,soundtrack], 'tt0054331': [       nconst   primaryName birthYear deathYear          primaryProfession
# 17  nm0000018  Kirk Douglas      1916        \N  actor,producer,soundtrack,        nconst       primaryName birthYear deathYear        primaryProfession
# 58  nm0000059  Laurence Olivier      1907      1989  actor,producer,director,         nconst  primaryName birthYear deathYear          primaryProfession
# 347  nm0000348  Tony Curtis      1925      2010  actor,soundtrack,producer], 'tt0052365': [       nconst   primaryName birthYear deathYear          primaryProfession
# 17  nm0000018  Kirk Douglas      1916        \N  actor,producer,soundtrack], 'tt0049456': [       nconst   primaryName birthYear deathYear          primaryProfession
# 17  nm0000018  Kirk Douglas      1916        \N  actor,producer,soundtrack,        nconst    primaryName birthYear deathYear          primaryProfession
# 62  nm0000063  Anthony Quinn      1915      2001  actor,producer,soundtrack], 'tt0071129': [       nconst       primaryName birthYear deathYear  \
# 18  nm0000019  Federico Fellini      1920      1993
#
#                      primaryProfession
# 18  writer,director,assistant_director  ], 'tt0056801': [       nconst       primaryName birthYear deathYear  \
# 18  nm0000019  Federico Fellini      1920      1993
#
#                      primaryProfession
# 18  writer,director,assistant_director  ,        nconst           primaryName birthYear deathYear  \
# 51  nm0000052  Marcello Mastroianni      1924      1996
#
#             primaryProfession
# 51  actor,soundtrack,producer  ,        nconst primaryName birthYear deathYear  \
# 64  nm0000065   Nino Rota      1911      1979
#
#                        primaryProfession
# 64  composer,soundtrack,music_department  ], 'tt0053779': [       nconst       primaryName birthYear deathYear  \
# 18  nm0000019  Federico Fellini      1920      1993
#
#                      primaryProfession
# 18  writer,director,assistant_director  ,        nconst           primaryName birthYear deathYear  \
# 51  nm0000052  Marcello Mastroianni      1924      1996
#
#             primaryProfession
# 51  actor,soundtrack,producer  ], 'tt0047528': [       nconst       primaryName birthYear deathYear  \
# 18  nm0000019  Federico Fellini      1920      1993
#
#                      primaryProfession
# 18  writer,director,assistant_director  ], 'tt0032551': [       nconst  primaryName birthYear deathYear          primaryProfession
# 19  nm0000020  Henry Fonda      1905      1982  actor,producer,soundtrack,         nconst primaryName birthYear deathYear         primaryProfession
# 405  nm0000406   John Ford      1894      1973  director,producer,writer], 'tt0050083': [       nconst  primaryName birthYear deathYear          primaryProfession
# 19  nm0000020  Henry Fonda      1905      1982  actor,producer,soundtrack], 'tt0064116': [       nconst  primaryName birthYear deathYear          primaryProfession
# 19  nm0000020  Henry Fonda      1905      1982  actor,producer,soundtrack,         nconst      primaryName birthYear deathYear primaryProfession
# 313  nm0000314  Charles Bronson      1921      2003             actor], 'tt0082846': [       nconst  primaryName birthYear deathYear          primaryProfession
# 19  nm0000020  Henry Fonda      1905      1982  actor,producer,soundtrack], 'tt0032976': [       nconst    primaryName birthYear deathYear            primaryProfession
# 20  nm0000021  Joan Fontaine      1917      2013  actress,soundtrack,producer,        nconst       primaryName birthYear deathYear        primaryProfession
# 58  nm0000059  Laurence Olivier      1907      1989  actor,producer,director,        nconst   primaryName birthYear deathYear  \
# 76  nm0000077  Franz Waxman      1906      1967
#
#                        primaryProfession
# 76  music_department,composer,soundtrack  ], 'tt0034248': [       nconst    primaryName birthYear deathYear            primaryProfession
# 20  nm0000021  Joan Fontaine      1917      2013  actress,soundtrack,producer,        nconst   primaryName birthYear deathYear  \
# 76  nm0000077  Franz Waxman      1906      1967
#
#                        primaryProfession
# 76  music_department,composer,soundtrack  ], 'tt0039504': [       nconst    primaryName birthYear deathYear            primaryProfession
# 20  nm0000021  Joan Fontaine      1917      2013  actress,soundtrack,producer], 'tt0036969': [       nconst    primaryName birthYear deathYear            primaryProfession
# 20  nm0000021  Joan Fontaine      1917      2013  actress,soundtrack,producer], 'tt0026205': [       nconst  primaryName birthYear deathYear          primaryProfession
# 21  nm0000022  Clark Gable      1901      1960  actor,soundtrack,producer], 'tt0026752': [       nconst  primaryName birthYear deathYear          primaryProfession
# 21  nm0000022  Clark Gable      1901      1960  actor,soundtrack,producer], 'tt0025316': [       nconst  primaryName birthYear deathYear          primaryProfession
# 21  nm0000022  Clark Gable      1901      1960  actor,soundtrack,producer], 'tt0047522': [       nconst   primaryName birthYear deathYear   primaryProfession
# 22  nm0000023  Judy Garland      1922      1969  soundtrack,actress,        nconst  primaryName birthYear deathYear      primaryProfession
# 50  nm0000051  James Mason      1909      1984  actor,producer,writer], 'tt0032138': [       nconst   primaryName birthYear deathYear   primaryProfession
# 22  nm0000023  Judy Garland      1922      1969  soundtrack,actress], 'tt0037059': [       nconst   primaryName birthYear deathYear   primaryProfession
# 22  nm0000023  Judy Garland      1922      1969  soundtrack,actress], 'tt0082031': [       nconst   primaryName birthYear deathYear      primaryProfession
# 23  nm0000024  John Gielgud      1904      2000  actor,writer,director], 'tt0045943': [       nconst   primaryName birthYear deathYear      primaryProfession
# 23  nm0000024  John Gielgud      1904      2000  actor,writer,director], 'tt0117631': [       nconst   primaryName birthYear deathYear      primaryProfession
# 23  nm0000024  John Gielgud      1904      2000  actor,writer,director,        nconst          primaryName birthYear deathYear      primaryProfession
# 89  nm0000090  Armin Mueller-Stahl      1930        \N  actor,director,writer], 'tt0117731': [       nconst      primaryName birthYear deathYear  \
# 24  nm0000025  Jerry Goldsmith      1929      2004
#
#                        primaryProfession
# 24  music_department,soundtrack,composer  ,         nconst   primaryName birthYear deathYear      primaryProfession
# 372  nm0000373  Michael Dorn      1952        \N  actor,director,writer,         nconst      primaryName birthYear deathYear        primaryProfession
# 407  nm0000408  Jonathan Frakes      1952        \N  actor,director,producer,         nconst  primaryName birthYear deathYear        primaryProfession
# 480  nm0000481  Alice Krige      1954        \N  actress,producer,writer], 'tt0119488': [       nconst      primaryName birthYear deathYear  \
# 24  nm0000025  Jerry Goldsmith      1929      2004
#
#                        primaryProfession
# 24  music_department,soundtrack,composer  ,         nconst   primaryName birthYear deathYear            primaryProfession
# 106  nm0000107  Kim Basinger      1953        \N  actress,soundtrack,producer,         nconst    primaryName birthYear deathYear          primaryProfession
# 127  nm0000128  Russell Crowe      1964        \N  actor,soundtrack,producer,         nconst   primaryName birthYear deathYear          primaryProfession
# 227  nm0000228  Kevin Spacey      1959        \N  actor,producer,soundtrack,         nconst   primaryName birthYear deathYear primaryProfession
# 282  nm0000283  Brenda Bakke      1963        \N           actress,         nconst     primaryName birthYear deathYear          primaryProfession
# 341  nm0000342  James Cromwell      1940        \N  actor,producer,soundtrack,         nconst    primaryName birthYear deathYear         primaryProfession
# 435  nm0000436  Curtis Hanson      1945      2016  director,producer,writer], 'tt0112715': [       nconst      primaryName birthYear deathYear  \
# 24  nm0000025  Jerry Goldsmith      1929      2004
#
#                        primaryProfession
# 24  music_department,soundtrack,composer  ,         nconst primaryName birthYear deathYear          primaryProfession
# 346  nm0000347   Tim Curry      1946        \N  actor,soundtrack,producer], 'tt0100802': [       nconst      primaryName birthYear deathYear  \
# 24  nm0000025  Jerry Goldsmith      1929      2004
#
#                        primaryProfession
# 24  music_department,soundtrack,composer  ,         nconst       primaryName birthYear deathYear      primaryProfession
# 460  nm0000461  Michael Ironside      1950        \N  actor,producer,writer], 'tt0056923': [       nconst primaryName birthYear deathYear          primaryProfession
# 25  nm0000026  Cary Grant      1904      1986  actor,soundtrack,producer,        nconst     primaryName birthYear deathYear   primaryProfession
# 29  nm0000030  Audrey Hepburn      1929      1993  actress,soundtrack], 'tt0036613': [       nconst primaryName birthYear deathYear          primaryProfession
# 25  nm0000026  Cary Grant      1904      1986  actor,soundtrack,producer,        nconst  primaryName birthYear deathYear        primaryProfession
# 47  nm0000048  Peter Lorre      1904      1964  actor,soundtrack,writer,        nconst  primaryName birthYear deathYear  \
# 69  nm0000070  Max Steiner      1888      1971
#
#                        primaryProfession
# 69  music_department,composer,soundtrack  ], 'tt0048728': [       nconst primaryName birthYear deathYear          primaryProfession
# 25  nm0000026  Cary Grant      1904      1986  actor,soundtrack,producer,        nconst  primaryName birthYear deathYear   primaryProfession
# 37  nm0000038  Grace Kelly      1929      1982  actress,soundtrack], 'tt0053125': [       nconst primaryName birthYear deathYear          primaryProfession
# 25  nm0000026  Cary Grant      1904      1986  actor,soundtrack,producer,        nconst       primaryName birthYear deathYear        primaryProfession
# 32  nm0000033  Alfred Hitchcock      1899      1980  actor,director,producer], 'tt0050212': [       nconst    primaryName birthYear deathYear        primaryProfession
# 26  nm0000027  Alec Guinness      1914      2000  actor,soundtrack,writer,         nconst primaryName birthYear deathYear       primaryProfession
# 179  nm0000180  David Lean      1908      1991  editor,director,writer], 'tt0051739': [       nconst    primaryName birthYear deathYear        primaryProfession
# 26  nm0000027  Alec Guinness      1914      2000  actor,soundtrack,writer], 'tt0076759': [       nconst    primaryName birthYear deathYear        primaryProfession
# 26  nm0000027  Alec Guinness      1914      2000  actor,soundtrack,writer,         nconst   primaryName birthYear deathYear         primaryProfession
# 183  nm0000184  George Lucas      1944        \N  writer,producer,director,         nconst      primaryName birthYear deathYear      primaryProfession
# 354  nm0000355  Anthony Daniels      1946        \N  actor,producer,writer,         nconst    primaryName birthYear deathYear          primaryProfession
# 401  nm0000402  Carrie Fisher      1956      2016  actress,soundtrack,writer,         nconst  primaryName birthYear deathYear          primaryProfession
# 433  nm0000434  Mark Hamill      1951        \N  actor,producer,soundtrack], 'tt0041546': [       nconst    primaryName birthYear deathYear        primaryProfession
# 26  nm0000027  Alec Guinness      1914      2000  actor,soundtrack,writer], 'tt0036723': [       nconst    primaryName birthYear deathYear            primaryProfession
# 27  nm0000028  Rita Hayworth      1918      1987  actress,soundtrack,producer], 'tt0038559': [       nconst    primaryName birthYear deathYear            primaryProfession
# 27  nm0000028  Rita Hayworth      1918      1987  actress,soundtrack,producer], 'tt0040552': [       nconst    primaryName birthYear deathYear            primaryProfession
# 27  nm0000028  Rita Hayworth      1918      1987  actress,soundtrack,producer], 'tt0040525': [       nconst    primaryName birthYear deathYear            primaryProfession
# 27  nm0000028  Rita Hayworth      1918      1987  actress,soundtrack,producer], 'tt0102122': [       nconst        primaryName birthYear deathYear      primaryProfession
# 28  nm0000029  Margaux Hemingway      1954      1996  actress,miscellaneous], 'tt0077800': [       nconst        primaryName birthYear deathYear      primaryProfession
# 28  nm0000029  Margaux Hemingway      1954      1996  actress,miscellaneous], 'tt0074802': [       nconst        primaryName birthYear deathYear      primaryProfession
# 28  nm0000029  Margaux Hemingway      1954      1996  actress,miscellaneous], 'tt0110138': [       nconst        primaryName birthYear deathYear      primaryProfession
# 28  nm0000029  Margaux Hemingway      1954      1996  actress,miscellaneous], 'tt0046250': [       nconst     primaryName birthYear deathYear   primaryProfession
# 29  nm0000030  Audrey Hepburn      1929      1993  actress,soundtrack,        nconst   primaryName birthYear deathYear          primaryProfession
# 59  nm0000060  Gregory Peck      1916      2003  actor,producer,soundtrack], 'tt0058385': [       nconst     primaryName birthYear deathYear   primaryProfession
# 29  nm0000030  Audrey Hepburn      1929      1993  actress,soundtrack], 'tt0054698': [       nconst     primaryName birthYear deathYear   primaryProfession
# 29  nm0000030  Audrey Hepburn      1929      1993  actress,soundtrack,        nconst    primaryName birthYear deathYear  \
# 48  nm0000049  Henry Mancini      1924      1994
#
#                        primaryProfession
# 48  music_department,soundtrack,composer  ], 'tt0032904': [       nconst        primaryName birthYear deathYear  \
# 30  nm0000031  Katharine Hepburn      1907      2003
#
#             primaryProfession
# 30  actress,soundtrack,writer  ,        nconst    primaryName birthYear deathYear          primaryProfession
# 70  nm0000071  James Stewart      1908      1997  actor,soundtrack,director], 'tt0061735': [       nconst        primaryName birthYear deathYear  \
# 30  nm0000031  Katharine Hepburn      1907      2003
#
#             primaryProfession
# 30  actress,soundtrack,writer  ,        nconst    primaryName birthYear deathYear primaryProfession
# 74  nm0000075  Spencer Tracy      1900      1967  actor,soundtrack], 'tt0063227': [       nconst        primaryName birthYear deathYear  \
# 30  nm0000031  Katharine Hepburn      1907      2003
#
#             primaryProfession
# 30  actress,soundtrack,writer  ], 'tt0063442': [       nconst      primaryName birthYear deathYear      primaryProfession
# 31  nm0000032  Charlton Heston      1923      2008  actor,director,writer], 'tt0070723': [       nconst      primaryName birthYear deathYear      primaryProfession
# 31  nm0000032  Charlton Heston      1923      2008  actor,director,writer,        nconst         primaryName birthYear deathYear        primaryProfession
# 63  nm0000064  Edward G. Robinson      1893      1973  actor,soundtrack,writer], 'tt0052618': [       nconst      primaryName birthYear deathYear      primaryProfession
# 31  nm0000032  Charlton Heston      1923      2008  actor,director,writer,        nconst   primaryName birthYear deathYear  \
# 66  nm0000067  Miklós Rózsa      1907      1995
#
#                        primaryProfession
# 66  music_department,composer,soundtrack  ], 'tt0049833': [       nconst      primaryName birthYear deathYear      primaryProfession
# 31  nm0000032  Charlton Heston      1923      2008  actor,director,writer], 'tt0054215': [       nconst       primaryName birthYear deathYear        primaryProfession
# 32  nm0000033  Alfred Hitchcock      1899      1980  actor,director,producer], 'tt0052357': [       nconst       primaryName birthYear deathYear        primaryProfession
# 32  nm0000033  Alfred Hitchcock      1899      1980  actor,director,producer,        nconst    primaryName birthYear deathYear          primaryProfession
# 70  nm0000071  James Stewart      1908      1997  actor,soundtrack,director], 'tt0030341': [       nconst       primaryName birthYear deathYear        primaryProfession
# 32  nm0000033  Alfred Hitchcock      1899      1980  actor,director,producer], 'tt0043014': [       nconst     primaryName birthYear deathYear primaryProfession
# 33  nm0000034  William Holden      1918      1981  actor,soundtrack,        nconst   primaryName birthYear deathYear  \
# 76  nm0000077  Franz Waxman      1906      1967
#
#                        primaryProfession
# 76  music_department,composer,soundtrack  ], 'tt0046359': [       nconst     primaryName birthYear deathYear primaryProfession
# 33  nm0000034  William Holden      1918      1981  actor,soundtrack], 'tt0074958': [       nconst     primaryName birthYear deathYear primaryProfession
# 33  nm0000034  William Holden      1918      1981  actor,soundtrack], 'tt0065214': [       nconst     primaryName birthYear deathYear primaryProfession
# 33  nm0000034  William Holden      1918      1981  actor,soundtrack,         nconst      primaryName birthYear deathYear          primaryProfession
# 307  nm0000308  Ernest Borgnine      1917      2012  actor,soundtrack,producer], 'tt0120338': [       nconst   primaryName birthYear deathYear  \
# 34  nm0000035  James Horner      1953      2015
#
#                        primaryProfession
# 34  music_department,soundtrack,composer  ,         nconst    primaryName birthYear deathYear         primaryProfession
# 115  nm0000116  James Cameron      1954        \N  writer,producer,director,         nconst        primaryName birthYear deathYear      primaryProfession
# 137  nm0000138  Leonardo DiCaprio      1974        \N  actor,producer,writer], 'tt0120647': [       nconst   primaryName birthYear deathYear  \
# 34  nm0000035  James Horner      1953      2015
#
#                        primaryProfession
# 34  music_department,soundtrack,composer  ,         nconst    primaryName birthYear deathYear primaryProfession
# 343  nm0000344  Denise Crosby      1957        \N  actress,producer,         nconst primaryName birthYear deathYear primaryProfession
# 494  nm0000495   Téa Leoni      1966        \N  actress,producer], 'tt0120746': [       nconst   primaryName birthYear deathYear  \
# 34  nm0000035  James Horner      1953      2015
#
#                        primaryProfession
# 34  music_department,soundtrack,composer  ,         nconst       primaryName birthYear deathYear  \
# 103  nm0000104  Antonio Banderas      1960        \N
#
#              primaryProfession
# 103  actor,soundtrack,producer  ], 'tt0499549': [       nconst   primaryName birthYear deathYear  \
# 34  nm0000035  James Horner      1953      2015
#
#                        primaryProfession
# 34  music_department,soundtrack,composer  ,         nconst    primaryName birthYear deathYear         primaryProfession
# 115  nm0000116  James Cameron      1954        \N  writer,producer,director,         nconst       primaryName birthYear deathYear  \
# 243  nm0000244  Sigourney Weaver      1949        \N
#
#                primaryProfession
# 243  actress,soundtrack,producer  ], 'tt0017925': [       nconst    primaryName birthYear deathYear      primaryProfession
# 35  nm0000036  Buster Keaton      1895      1966  actor,writer,director], 'tt0015324': [       nconst    primaryName birthYear deathYear      primaryProfession
# 35  nm0000036  Buster Keaton      1895      1966  actor,writer,director], 'tt0015863': [       nconst    primaryName birthYear deathYear      primaryProfession
# 35  nm0000036  Buster Keaton      1895      1966  actor,writer,director], 'tt0016332': [       nconst    primaryName birthYear deathYear      primaryProfession
# 35  nm0000036  Buster Keaton      1895      1966  actor,writer,director], 'tt0045152': [       nconst primaryName birthYear deathYear          primaryProfession
# 36  nm0000037  Gene Kelly      1912      1996  actor,soundtrack,director], 'tt0041716': [       nconst primaryName birthYear deathYear          primaryProfession
# 36  nm0000037  Gene Kelly      1912      1996  actor,soundtrack,director], 'tt0041944': [       nconst primaryName birthYear deathYear          primaryProfession
# 36  nm0000037  Gene Kelly      1912      1996  actor,soundtrack,director], 'tt0043278': [       nconst primaryName birthYear deathYear          primaryProfession
# 36  nm0000037  Gene Kelly      1912      1996  actor,soundtrack,director], 'tt0046912': [       nconst  primaryName birthYear deathYear   primaryProfession
# 37  nm0000038  Grace Kelly      1929      1982  actress,soundtrack], 'tt0047396': [       nconst  primaryName birthYear deathYear   primaryProfession
# 37  nm0000038  Grace Kelly      1929      1982  actress,soundtrack], 'tt0050490': [       nconst   primaryName birthYear deathYear   primaryProfession
# 38  nm0000039  Deborah Kerr      1921      2007  actress,soundtrack,        nconst     primaryName birthYear deathYear          primaryProfession
# 52  nm0000053  Robert Mitchum      1917      1997  actor,soundtrack,producer], 'tt0049408': [       nconst   primaryName birthYear deathYear   primaryProfession
# 38  nm0000039  Deborah Kerr      1921      2007  actress,soundtrack], 'tt0039192': [       nconst   primaryName birthYear deathYear   primaryProfession
# 38  nm0000039  Deborah Kerr      1921      2007  actress,soundtrack], 'tt0045793': [       nconst   primaryName birthYear deathYear   primaryProfession
# 38  nm0000039  Deborah Kerr      1921      2007  actress,soundtrack,        nconst     primaryName birthYear deathYear  \
# 43  nm0000044  Burt Lancaster      1913      1994
#
#                primaryProfession
# 43  actor,producer,miscellaneous  ,        nconst    primaryName birthYear deathYear          primaryProfession
# 68  nm0000069  Frank Sinatra      1915      1998  soundtrack,actor,producer], 'tt0120663': [       nconst      primaryName birthYear deathYear         primaryProfession
# 39  nm0000040  Stanley Kubrick      1928      1999  director,writer,producer], 'tt0072684': [       nconst      primaryName birthYear deathYear         primaryProfession
# 39  nm0000040  Stanley Kubrick      1928      1999  director,writer,producer], 'tt0062622': [       nconst      primaryName birthYear deathYear         primaryProfession
# 39  nm0000040  Stanley Kubrick      1928      1999  director,writer,producer], 'tt0066921': [       nconst      primaryName birthYear deathYear         primaryProfession
# 39  nm0000040  Stanley Kubrick      1928      1999  director,writer,producer], 'tt0080979': [       nconst     primaryName birthYear deathYear  \
# 40  nm0000041  Akira Kurosawa      1910      1998
#
#                      primaryProfession
# 40  writer,director,assistant_director  ], 'tt0089881': [       nconst     primaryName birthYear deathYear  \
# 40  nm0000041  Akira Kurosawa      1910      1998
#
#                      primaryProfession
# 40  writer,director,assistant_director  ], 'tt0051808': [       nconst     primaryName birthYear deathYear  \
# 40  nm0000041  Akira Kurosawa      1910      1998
#
#                      primaryProfession
# 40  writer,director,assistant_director  ], 'tt0042876': [       nconst     primaryName birthYear deathYear  \
# 40  nm0000041  Akira Kurosawa      1910      1998
#
#                      primaryProfession
# 40  writer,director,assistant_director  ], 'tt0043292': [       nconst primaryName birthYear deathYear  \
# 41  nm0000042   Alan Ladd      1913      1964
#
#                    primaryProfession
# 41  actor,producer,camera_department  ], 'tt0038369': [       nconst primaryName birthYear deathYear  \
# 41  nm0000042   Alan Ladd      1913      1964
#
#                    primaryProfession
# 41  actor,producer,camera_department  ,        nconst    primaryName birthYear deathYear            primaryProfession
# 42  nm0000043  Veronica Lake      1922      1973  actress,soundtrack,producer], 'tt0035432': [       nconst primaryName birthYear deathYear  \
# 41  nm0000042   Alan Ladd      1913      1964
#
#                    primaryProfession
# 41  actor,producer,camera_department  ,        nconst    primaryName birthYear deathYear            primaryProfession
# 42  nm0000043  Veronica Lake      1922      1973  actress,soundtrack,producer], 'tt0046303': [       nconst primaryName birthYear deathYear  \
# 41  nm0000042   Alan Ladd      1913      1964
#
#                    primaryProfession
# 41  actor,producer,camera_department  ], 'tt0034881': [       nconst    primaryName birthYear deathYear            primaryProfession
# 42  nm0000043  Veronica Lake      1922      1973  actress,soundtrack,producer], 'tt0034240': [       nconst    primaryName birthYear deathYear            primaryProfession
# 42  nm0000043  Veronica Lake      1922      1973  actress,soundtrack,producer], 'tt0050468': [       nconst     primaryName birthYear deathYear  \
# 43  nm0000044  Burt Lancaster      1913      1994
#
#                primaryProfession
# 43  actor,producer,miscellaneous  ], 'tt0053793': [       nconst     primaryName birthYear deathYear  \
# 43  nm0000044  Burt Lancaster      1913      1994
#
#                primaryProfession
# 43  actor,producer,miscellaneous  ], 'tt0059825': [       nconst     primaryName birthYear deathYear  \
# 43  nm0000044  Burt Lancaster      1913      1994
#
#                primaryProfession
# 43  actor,producer,miscellaneous  ], 'tt0070034': [       nconst primaryName birthYear deathYear             primaryProfession
# 44  nm0000045   Bruce Lee      1940      1973  actor,miscellaneous,producer], 'tt0068935': [       nconst primaryName birthYear deathYear             primaryProfession
# 44  nm0000045   Bruce Lee      1940      1973  actor,miscellaneous,producer], 'tt0077594': [       nconst primaryName birthYear deathYear             primaryProfession
# 44  nm0000045   Bruce Lee      1940      1973  actor,miscellaneous,producer], 'tt0068767': [       nconst primaryName birthYear deathYear             primaryProfession
# 44  nm0000045   Bruce Lee      1940      1973  actor,miscellaneous,producer], 'tt0055382': [       nconst   primaryName birthYear deathYear          primaryProfession
# 45  nm0000046  Vivien Leigh      1913      1967  actress,soundtrack,writer], 'tt0033238': [       nconst   primaryName birthYear deathYear          primaryProfession
# 45  nm0000046  Vivien Leigh      1913      1967  actress,soundtrack,writer], 'tt0044081': [       nconst   primaryName birthYear deathYear          primaryProfession
# 45  nm0000046  Vivien Leigh      1913      1967  actress,soundtrack,writer], 'tt0875034': [       nconst   primaryName birthYear deathYear   primaryProfession
# 46  nm0000047  Sophia Loren      1934        \N  actress,soundtrack], 'tt0058335': [       nconst   primaryName birthYear deathYear   primaryProfession
# 46  nm0000047  Sophia Loren      1934        \N  actress,soundtrack], 'tt0054749': [       nconst   primaryName birthYear deathYear   primaryProfession
# 46  nm0000047  Sophia Loren      1934        \N  actress,soundtrack], 'tt0060121': [       nconst   primaryName birthYear deathYear   primaryProfession
# 46  nm0000047  Sophia Loren      1934        \N  actress,soundtrack], 'tt0022100': [       nconst  primaryName birthYear deathYear        primaryProfession
# 47  nm0000048  Peter Lorre      1904      1964  actor,soundtrack,writer,         nconst primaryName birthYear deathYear         primaryProfession
# 484  nm0000485  Fritz Lang      1890      1976  director,writer,producer], 'tt0057413': [       nconst    primaryName birthYear deathYear  \
# 48  nm0000049  Henry Mancini      1924      1994
#
#                        primaryProfession
# 48  music_department,soundtrack,composer  ,        nconst  primaryName birthYear deathYear          primaryProfession
# 56  nm0000057  David Niven      1910      1983  actor,producer,soundtrack], 'tt0085101': [       nconst    primaryName birthYear deathYear  \
# 48  nm0000049  Henry Mancini      1924      1994
#
#                        primaryProfession
# 48  music_department,soundtrack,composer  ,         nconst          primaryName birthYear deathYear  \
# 327  nm0000328  Richard Chamberlain      1934        \N
#
#              primaryProfession
# 327  actor,soundtrack,producer  ], 'tt0383216': [       nconst    primaryName birthYear deathYear  \
# 48  nm0000049  Henry Mancini      1924      1994
#
#                        primaryProfession
# 48  music_department,soundtrack,composer  ,         nconst   primaryName birthYear deathYear        primaryProfession
# 187  nm0000188  Steve Martin      1945        \N  writer,actor,soundtrack], 'tt0032536': [       nconst   primaryName birthYear deathYear        primaryProfession
# 49  nm0000050  Groucho Marx      1890      1977  soundtrack,actor,writer], 'tt0022158': [       nconst   primaryName birthYear deathYear        primaryProfession
# 49  nm0000050  Groucho Marx      1890      1977  soundtrack,actor,writer], 'tt0026778': [       nconst   primaryName birthYear deathYear        primaryProfession
# 49  nm0000050  Groucho Marx      1890      1977  soundtrack,actor,writer], 'tt0023969': [       nconst   primaryName birthYear deathYear        primaryProfession
# 49  nm0000050  Groucho Marx      1890      1977  soundtrack,actor,writer], 'tt0046672': [       nconst  primaryName birthYear deathYear      primaryProfession
# 50  nm0000051  James Mason      1909      1984  actor,producer,writer], 'tt0056193': [       nconst  primaryName birthYear deathYear      primaryProfession
# 50  nm0000051  James Mason      1909      1984  actor,producer,writer], 'tt0084855': [       nconst  primaryName birthYear deathYear      primaryProfession
# 50  nm0000051  James Mason      1909      1984  actor,producer,writer,        nconst  primaryName birthYear deathYear        primaryProfession
# 55  nm0000056  Paul Newman      1925      2008  actor,producer,director], 'tt0057171': [       nconst           primaryName birthYear deathYear  \
# 51  nm0000052  Marcello Mastroianni      1924      1996
#
#             primaryProfession
# 51  actor,soundtrack,producer  ], 'tt0050782': [       nconst           primaryName birthYear deathYear  \
# 51  nm0000052  Marcello Mastroianni      1924      1996
#
#             primaryProfession
# 51  actor,soundtrack,producer  ], 'tt0056197': [       nconst     primaryName birthYear deathYear          primaryProfession
# 52  nm0000053  Robert Mitchum      1917      1997  actor,soundtrack,producer], 'tt0048424': [       nconst     primaryName birthYear deathYear          primaryProfession
# 52  nm0000053  Robert Mitchum      1917      1997  actor,soundtrack,producer], 'tt0039689': [       nconst     primaryName birthYear deathYear          primaryProfession
# 52  nm0000053  Robert Mitchum      1917      1997  actor,soundtrack,producer], 'tt0045810': [       nconst     primaryName birthYear deathYear          primaryProfession
# 53  nm0000054  Marilyn Monroe      1926      1962  soundtrack,actress,writer,        nconst   primaryName birthYear deathYear            primaryProfession
# ...
# 464  nm0000465  Ron Jeremy      1953        \N  actor,director,writer], 'tt0144117': [        nconst primaryName birthYear deathYear      primaryProfession
# 464  nm0000465  Ron Jeremy      1953        \N  actor,director,writer], 'tt0124819': [        nconst primaryName birthYear deathYear      primaryProfession
# 464  nm0000465  Ron Jeremy      1953        \N  actor,director,writer], 'tt0211915': [        nconst         primaryName birthYear deathYear  \
# 465  nm0000466  Jean-Pierre Jeunet      1953        \N
#
#             primaryProfession
# 465  director,writer,producer  ], 'tt0101700': [        nconst         primaryName birthYear deathYear  \
# 465  nm0000466  Jean-Pierre Jeunet      1953        \N
#
#             primaryProfession
# 465  director,writer,producer  ], 'tt0344510': [        nconst         primaryName birthYear deathYear  \
# 465  nm0000466  Jean-Pierre Jeunet      1953        \N
#
#             primaryProfession
# 465  director,writer,producer  ], 'tt1149361': [        nconst         primaryName birthYear deathYear  \
# 465  nm0000466  Jean-Pierre Jeunet      1953        \N
#
#             primaryProfession
# 465  director,writer,producer  ], 'tt0086759': [        nconst  primaryName birthYear deathYear          primaryProfession
# 466  nm0000467  Don Johnson      1949        \N  actor,producer,soundtrack], 'tt0072730': [        nconst  primaryName birthYear deathYear          primaryProfession
# 466  nm0000467  Don Johnson      1949        \N  actor,producer,soundtrack], 'tt0985694': [        nconst  primaryName birthYear deathYear          primaryProfession
# 466  nm0000467  Don Johnson      1949        \N  actor,producer,soundtrack], 'tt1853728': [        nconst  primaryName birthYear deathYear          primaryProfession
# 466  nm0000467  Don Johnson      1949        \N  actor,producer,soundtrack], 'tt0077716': [        nconst         primaryName birthYear deathYear primaryProfession
# 467  nm0000468  Lynn-Holly Johnson      1958        \N  actress,director], 'tt0082398': [        nconst         primaryName birthYear deathYear primaryProfession
# 467  nm0000468  Lynn-Holly Johnson      1958        \N  actress,director], 'tt0088395': [        nconst         primaryName birthYear deathYear primaryProfession
# 467  nm0000468  Lynn-Holly Johnson      1958        \N  actress,director], 'tt0081738': [        nconst         primaryName birthYear deathYear primaryProfession
# 467  nm0000468  Lynn-Holly Johnson      1958        \N  actress,director], 'tt3748528': [        nconst       primaryName birthYear deathYear primaryProfession
# 468  nm0000469  James Earl Jones      1931        \N  actor,soundtrack], 'tt0094898': [        nconst       primaryName birthYear deathYear primaryProfession
# 468  nm0000469  James Earl Jones      1931        \N  actor,soundtrack], 'tt0086879': [        nconst    primaryName birthYear deathYear primaryProfession
# 469  nm0000470  Jeffrey Jones      1946        \N             actor], 'tt0091225': [        nconst    primaryName birthYear deathYear primaryProfession
# 469  nm0000470  Jeffrey Jones      1946        \N             actor], 'tt0089424': [        nconst primaryName birthYear deathYear primaryProfession
# 470  nm0000471  Raul Julia      1940      1994  actor,soundtrack], 'tt0111301': [        nconst primaryName birthYear deathYear primaryProfession
# 470  nm0000471  Raul Julia      1940      1994  actor,soundtrack], 'tt0023245': [        nconst    primaryName birthYear deathYear primaryProfession
# 471  nm0000472  Boris Karloff      1887      1969  actor,soundtrack], 'tt0026138': [        nconst    primaryName birthYear deathYear primaryProfession
# 471  nm0000472  Boris Karloff      1887      1969  actor,soundtrack], 'tt0024894': [        nconst    primaryName birthYear deathYear primaryProfession
# 471  nm0000472  Boris Karloff      1887      1969  actor,soundtrack], 'tt0060345': [        nconst    primaryName birthYear deathYear primaryProfession
# 471  nm0000472  Boris Karloff      1887      1969  actor,soundtrack], 'tt0337741': [        nconst   primaryName birthYear deathYear          primaryProfession
# 472  nm0000473  Diane Keaton      1946        \N  actress,producer,director], 'tt0356680': [        nconst   primaryName birthYear deathYear          primaryProfession
# 472  nm0000473  Diane Keaton      1946        \N  actress,producer,director], 'tt2562232': [        nconst     primaryName birthYear deathYear          primaryProfession
# 473  nm0000474  Michael Keaton      1951        \N  actor,producer,soundtrack], 'tt0094721': [        nconst     primaryName birthYear deathYear          primaryProfession
# 473  nm0000474  Michael Keaton      1951        \N  actor,producer,soundtrack], 'tt1895587': [        nconst     primaryName birthYear deathYear          primaryProfession
# 473  nm0000474  Michael Keaton      1951        \N  actor,producer,soundtrack], 'tt4276820': [        nconst     primaryName birthYear deathYear          primaryProfession
# 473  nm0000474  Michael Keaton      1951        \N  actor,producer,soundtrack], 'tt0090585': [        nconst   primaryName birthYear deathYear   primaryProfession
# 474  nm0000475  Patsy Kensit      1968        \N  actress,soundtrack], 'tt0068069': [        nconst   primaryName birthYear deathYear   primaryProfession
# 474  nm0000475  Patsy Kensit      1968        \N  actress,soundtrack], 'tt0079268': [        nconst   primaryName birthYear deathYear   primaryProfession
# 474  nm0000475  Patsy Kensit      1968        \N  actress,soundtrack], 'tt0097733': [        nconst   primaryName birthYear deathYear   primaryProfession
# 474  nm0000475  Patsy Kensit      1968        \N  actress,soundtrack], 'tt0131369': [        nconst     primaryName birthYear deathYear  \
# 475  nm0000476  Sally Kirkland      1941        \N
#
#                   primaryProfession
# 475  actress,producer,miscellaneous  ], 'tt0092569': [        nconst     primaryName birthYear deathYear  \
# 475  nm0000476  Sally Kirkland      1941        \N
#
#                   primaryProfession
# 475  actress,producer,miscellaneous  ], 'tt3216866': [        nconst     primaryName birthYear deathYear  \
# 475  nm0000476  Sally Kirkland      1941        \N
#
#                   primaryProfession
# 475  actress,producer,miscellaneous  ], 'tt0387877': [        nconst   primaryName birthYear deathYear primaryProfession
# 476  nm0000477  Mia Kirshner      1975        \N           actress], 'tt0330251': [        nconst   primaryName birthYear deathYear primaryProfession
# 476  nm0000477  Mia Kirshner      1975        \N           actress], 'tt3520702': [        nconst   primaryName birthYear deathYear primaryProfession
# 476  nm0000477  Mia Kirshner      1975        \N           actress], 'tt0086793': [        nconst   primaryName birthYear deathYear primaryProfession
# 477  nm0000478  Tawny Kitaen      1961        \N  actress,producer], 'tt0086927': [        nconst   primaryName birthYear deathYear primaryProfession
# 477  nm0000478  Tawny Kitaen      1961        \N  actress,producer], 'tt0087903': [        nconst   primaryName birthYear deathYear primaryProfession
# 477  nm0000478  Tawny Kitaen      1961        \N  actress,producer], 'tt0111999': [        nconst   primaryName birthYear deathYear primaryProfession
# 477  nm0000478  Tawny Kitaen      1961        \N  actress,producer], 'tt0060028': [        nconst    primaryName birthYear deathYear      primaryProfession
# 478  nm0000479  Walter Koenig      1936        \N  actor,writer,producer], 'tt0092007': [        nconst    primaryName birthYear deathYear      primaryProfession
# 478  nm0000479  Walter Koenig      1936        \N  actor,writer,producer], 'tt0822854': [        nconst   primaryName birthYear deathYear primaryProfession
# 479  nm0000480  Elias Koteas      1961        \N    actor,producer], 'tt0114194': [        nconst   primaryName birthYear deathYear primaryProfession
# 479  nm0000480  Elias Koteas      1961        \N    actor,producer], 'tt0120863': [        nconst   primaryName birthYear deathYear primaryProfession
# 479  nm0000480  Elias Koteas      1961        \N    actor,producer], 'tt0105428': [        nconst  primaryName birthYear deathYear        primaryProfession
# 480  nm0000481  Alice Krige      1954        \N  actress,producer,writer], 'tt1981115': [        nconst  primaryName birthYear deathYear        primaryProfession
# 480  nm0000481  Alice Krige      1954        \N  actress,producer,writer], 'tt0384537': [        nconst  primaryName birthYear deathYear        primaryProfession
# 480  nm0000481  Alice Krige      1954        \N  actress,producer,writer], 'tt0079152': [        nconst     primaryName birthYear deathYear  \
# 481  nm0000482  Sylvia Kristel      1952      2012
#
#                primaryProfession
# 481  actress,soundtrack,director  ], 'tt0071464': [        nconst     primaryName birthYear deathYear  \
# 481  nm0000482  Sylvia Kristel      1952      2012
#
#                primaryProfession
# 481  actress,soundtrack,director  ], 'tt0072933': [        nconst     primaryName birthYear deathYear  \
# 481  nm0000482  Sylvia Kristel      1952      2012
#
#                primaryProfession
# 481  actress,soundtrack,director  ], 'tt0078740': [        nconst     primaryName birthYear deathYear  \
# 481  nm0000482  Sylvia Kristel      1952      2012
#
#                primaryProfession
# 481  actress,soundtrack,director  ], 'tt0120604': [        nconst          primaryName birthYear deathYear      primaryProfession
# 482  nm0000483  Christopher Lambert      1957        \N  actor,producer,writer], 'tt0091203': [        nconst          primaryName birthYear deathYear      primaryProfession
# 482  nm0000483  Christopher Lambert      1957        \N  actor,producer,writer], 'tt0090095': [        nconst          primaryName birthYear deathYear      primaryProfession
# 482  nm0000483  Christopher Lambert      1957        \N  actor,producer,writer], 'tt0113855': [        nconst          primaryName birthYear deathYear      primaryProfession
# 482  nm0000483  Christopher Lambert      1957        \N  actor,producer,writer], 'tt0086491': [        nconst  primaryName birthYear deathYear        primaryProfession
# 483  nm0000484  John Landis      1950        \N  producer,director,actor], 'tt0019901': [        nconst primaryName birthYear deathYear         primaryProfession
# 484  nm0000485  Fritz Lang      1890      1976  director,writer,producer], 'tt0017136': [        nconst primaryName birthYear deathYear         primaryProfession
# 484  nm0000485  Fritz Lang      1890      1976  director,writer,producer], 'tt0094490': [        nconst         primaryName birthYear deathYear  \
# 485  nm0000486  Heather Langenkamp      1964        \N
#
#                               primaryProfession
# 485  actress,special_effects,make_up_department  ], 'tt0114388': [        nconst primaryName birthYear deathYear         primaryProfession
# 486  nm0000487     Ang Lee      1954        \N  director,producer,writer], 'tt0454876': [        nconst primaryName birthYear deathYear         primaryProfession
# 486  nm0000487     Ang Lee      1954        \N  director,producer,writer], 'tt0808357': [        nconst primaryName birthYear deathYear         primaryProfession
# 486  nm0000487     Ang Lee      1954        \N  director,producer,writer], 'tt0091428': [        nconst  primaryName birthYear deathYear    primaryProfession
# 487  nm0000488  Brandon Lee      1965      1993  actor,miscellaneous], 'tt0105219': [        nconst  primaryName birthYear deathYear    primaryProfession
# 487  nm0000488  Brandon Lee      1965      1993  actor,miscellaneous], 'tt0109506': [        nconst  primaryName birthYear deathYear    primaryProfession
# 487  nm0000488  Brandon Lee      1965      1993  actor,miscellaneous,         nconst primaryName birthYear deathYear        primaryProfession
# 498  nm0000499    Bai Ling      1966        \N  actress,producer,writer], 'tt0102915': [        nconst  primaryName birthYear deathYear    primaryProfession
# 487  nm0000488  Brandon Lee      1965      1993  actor,miscellaneous], 'tt0070917': [        nconst      primaryName birthYear deathYear          primaryProfession
# 488  nm0000489  Christopher Lee      1922      2015  actor,soundtrack,producer], 'tt0097216': [        nconst primaryName birthYear deathYear         primaryProfession
# 489  nm0000490   Spike Lee      1957        \N  director,producer,writer], 'tt0091939': [        nconst primaryName birthYear deathYear         primaryProfession
# 489  nm0000490   Spike Lee      1957        \N  director,producer,writer], 'tt7349662': [        nconst primaryName birthYear deathYear         primaryProfession
# 489  nm0000490   Spike Lee      1957        \N  director,producer,writer], 'tt0120177': [        nconst     primaryName birthYear deathYear      primaryProfession
# 490  nm0000491  John Leguizamo      1964        \N  actor,writer,producer], 'tt0119887': [        nconst     primaryName birthYear deathYear      primaryProfession
# 490  nm0000491  John Leguizamo      1964        \N  actor,writer,producer], 'tt2401878': [        nconst           primaryName birthYear deathYear  \
# 491  nm0000492  Jennifer Jason Leigh      1962        \N
#
#                primaryProfession
# 491  actress,producer,soundtrack  ], 'tt0053604': [        nconst  primaryName birthYear deathYear          primaryProfession
# 492  nm0000493  Jack Lemmon      1925      2001  actor,soundtrack,producer], 'tt0108265': [        nconst          primaryName birthYear deathYear primaryProfession
# 493  nm0000494  Robert Sean Leonard      1969        \N  actor,soundtrack], 'tt0106226': [        nconst          primaryName birthYear deathYear primaryProfession
# 493  nm0000494  Robert Sean Leonard      1969        \N  actor,soundtrack], 'tt0097165': [        nconst          primaryName birthYear deathYear primaryProfession
# 493  nm0000494  Robert Sean Leonard      1969        \N  actor,soundtrack], 'tt0412142': [        nconst          primaryName birthYear deathYear primaryProfession
# 493  nm0000494  Robert Sean Leonard      1969        \N  actor,soundtrack], 'tt0163025': [        nconst primaryName birthYear deathYear primaryProfession
# 494  nm0000495   Téa Leoni      1966        \N  actress,producer], 'tt0371246': [        nconst primaryName birthYear deathYear primaryProfession
# 494  nm0000495   Téa Leoni      1966        \N  actress,producer], 'tt0218967': [        nconst primaryName birthYear deathYear primaryProfession
# 494  nm0000495   Téa Leoni      1966        \N  actress,producer], 'tt0127385': [        nconst    primaryName birthYear deathYear  \
# 496  nm0000497  Jennifer Lien      1974        \N
#
#                   primaryProfession
# 496  actress,producer,miscellaneous  ], 'tt0106100': [        nconst    primaryName birthYear deathYear  \
# 496  nm0000497  Jennifer Lien      1974        \N
#
#                   primaryProfession
# 496  actress,producer,miscellaneous  ], 'tt0133189': [        nconst      primaryName birthYear deathYear          primaryProfession
# 497  nm0000498  Matthew Lillard      1970        \N  actor,producer,soundtrack], 'tt0331632': [        nconst      primaryName birthYear deathYear          primaryProfession
# 497  nm0000498  Matthew Lillard      1970        \N  actor,producer,soundtrack], 'tt0405336': [        nconst primaryName birthYear deathYear        primaryProfession
# 498  nm0000499    Bai Ling      1966        \N  actress,producer,writer], 'tt0119994': [        nconst primaryName birthYear deathYear        primaryProfession
# 498  nm0000499    Bai Ling      1966        \N  actress,producer,writer], 'tt0405296': [        nconst        primaryName birthYear deathYear  \
# 499  nm0000500  Richard Linklater      1960        \N
#
#             primaryProfession
# 499  producer,director,writer  ], 'tt0243017': [        nconst        primaryName birthYear deathYear  \
# 499  nm0000500  Richard Linklater      1960        \N
#
#             primaryProfession
# 499  producer,director,writer  ]})

# %%
novo=

# %%
#Abrir o arquivo
ratings = pd.read_csv('ratings.tsv',sep='\t')
#listar colunas
print(list(ratings))
# Out:
# ['tconst', 'averageRating', 'numVotes']

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.8      1431
# 1  tt0000002            6.3       170
# 2  tt0000003            6.6      1027
# 3  tt0000004            6.4       101
# 4  tt0000005            6.2      1723

# %%
#Abrir o arquivo
akas = pd.read_csv('title.akas.tsv',sep='\t')
#listar colunas
#print(list(akas))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
akas.head(10)
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1  Carmencita - spanyol tánc     HU       \N
# 1  tt0000001         2                 Карменсита     RU       \N
# 2  tt0000001         3                 Carmencita     US       \N
# 3  tt0000001         4                 Carmencita     \N       \N
# 4  tt0000002         1     Le clown et ses chiens     \N       \N
# 5  tt0000002         2          A bohóc és kutyái     HU       \N
# 6  tt0000002         3     Le clown et ses chiens     FR       \N
# 7  tt0000002         4      Clovnul si cainii sai     RO       \N
# 8  tt0000002         5     The Clown and His Dogs     US       \N
# 9  tt0000002         6         Клоун и его собаки     RU       \N
#
#          types             attributes isOriginalTitle
# 0  imdbDisplay                     \N               0
# 1           \N                     \N               0
# 2           \N                     \N               0
# 3     original                     \N               1
# 4     original                     \N               1
# 5  imdbDisplay                     \N               0
# 6           \N                     \N               0
# 7  imdbDisplay                     \N               0
# 8           \N  literal English title               0
# 9           \N                     \N               0

# %%
#Abrir o arquivo
basic = pd.read_csv('title.basics.tsv',sep='\t')
#listar colunas
print(list(basic))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ['tconst', 'titleType', 'primaryTitle', 'originalTitle', 'isAdult', 'startYear', 'endYear', 'runtimeMinutes', 'genres']

# %%
basic.head(10)
# Out:
#       tconst titleType                                 primaryTitle  \
# 0  tt0000001     short                                   Carmencita
# 1  tt0000002     short                       Le clown et ses chiens
# 2  tt0000003     short                               Pauvre Pierrot
# 3  tt0000004     short                                  Un bon bock
# 4  tt0000005     short                             Blacksmith Scene
# 5  tt0000006     short                            Chinese Opium Den
# 6  tt0000007     short  Corbett and Courtney Before the Kinetograph
# 7  tt0000008     short       Edison Kinetoscopic Record of a Sneeze
# 8  tt0000009     movie                                   Miss Jerry
# 9  tt0000010     short        Employees Leaving the Lumière Factory
#
#                                  originalTitle  isAdult startYear endYear  \
# 0                                   Carmencita        0      1894      \N
# 1                       Le clown et ses chiens        0      1892      \N
# 2                               Pauvre Pierrot        0      1892      \N
# 3                                  Un bon bock        0      1892      \N
# 4                             Blacksmith Scene        0      1893      \N
# 5                            Chinese Opium Den        0      1894      \N
# 6  Corbett and Courtney Before the Kinetograph        0      1894      \N
# 7       Edison Kinetoscopic Record of a Sneeze        0      1894      \N
# 8                                   Miss Jerry        0      1894      \N
# 9          La sortie de l'usine Lumière à Lyon        0      1895      \N
#
#   runtimeMinutes                    genres
# 0              1         Documentary,Short
# 1              5           Animation,Short
# 2              4  Animation,Comedy,Romance
# 3             \N           Animation,Short
# 4              1              Comedy,Short
# 5              1                     Short
# 6              1               Short,Sport
# 7              1         Documentary,Short
# 8             45                   Romance
# 9              1         Documentary,Short

# %%
#Abrir o arquivo
crew = pd.read_csv('title.crew.tsv',sep='\t')
#listar colunas
print(list(crew))

# %%
crew.head(10)

# %%
#Abrir o arquivo
principals = pd.read_csv('title.principals.tsv',sep='\t')
#listar colunas
print(list(principals))3

# %%
principals.head(10)

# %%
#Abrir o arquivo
imdb = pd.read_csv('movie_metadata.csv')
#listar colunas
print(list(metadata))

# %%
imdb.iloc[:,10:15].head()
